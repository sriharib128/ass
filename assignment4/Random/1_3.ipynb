# %%
import pandas as pd
import matplotlib.pyplot as plt
import math

a=pd.read_csv("./pi.csv")

fig, ax = plt.subplots(1,figsize=(15,5))
fig.set(facecolor = "white")
ax.set(ylim=[3.05,3.16])
a.plot( kind ='line',x='N',y='estimate',ax=ax);

a.plot( kind ='line',x='N',y='actual',ax=ax);
fig.savefig("./pi.png")
