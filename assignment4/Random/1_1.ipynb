# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
a=pd.read_csv("./six.csv")

fig, (ax,ax1) = plt.subplots(1,2,figsize=(15,6))
fig.set(facecolor = "white")

ax.set(ylim=[166000,167100])
a.plot( kind ='bar',x='no',y='rand',ax=ax,width=0.98);

ax1.set(ylim=[166000,167100])
a.plot( kind ='bar',x='no',y='theoretical',ax=ax1,width=0.98);
fig.savefig("./six.png")
