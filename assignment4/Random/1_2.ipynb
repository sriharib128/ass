# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
a=pd.read_csv("./twelve.csv")

fig, (ax,ax1) = plt.subplots(1,2,figsize=(15,6))
fig.set(facecolor = "white")

a.plot( kind ='bar',x='no',y='rand',ax=ax,width=0.97);

a.plot( kind ='bar',x='no',y='theoretical',ax=ax1,width=0.97);
fig.savefig("./twelve.png")
